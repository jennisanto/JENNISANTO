# %% [markdown]
# <a href="https://colab.research.google.com/github/jennisanto/JENNISANTO/blob/main/Aula.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Word")
# Out:
# Hello Word

# %%
# abertura de dados
dados = open("dados.txt", "r")
# ler dados
conteudo = dados.read()
# mostrando os dados
print(conteudo)
#fechando os dados
dados.close()
# Out:
# Meu primeiro arquivo txt

# %%
# abertura de dados
dados = open("dados.txt", "w")
# escrevendo dados
dados.write("/n Escrevend no arquivo texte /n")
# fechando os dados
dados.close()

# %%
segundoArquivo = open("segundoArquivoTexto.txt", "r")
linha = segundoArquivo.readline();
#Imprimindo a linha
print(linha)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-f94a7f51368f> in <cell line: 0>()
# ----> 1 segundoArquivo = open("segundoArquivoTexto.txt", "r")
#       2 linha = segundoArquivo.readline();
#       3 #Imprimindo a linha
#       4 print(linha)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'segundoArquivoTexto.txt'
