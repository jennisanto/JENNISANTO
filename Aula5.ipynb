# %% [markdown]
# <a href="https://colab.research.google.com/github/jennisanto/JENNISANTO/blob/main/Aula5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#criar e modificar arquivos
valores_celulares = [850, 2230, 1500, 3500, 5000]
#'r' -> Ler algo
#'w' -> somente escrever algo
#'r+' -> usado para ler e escrever algo
#'a' - > usado para acrescentar algo
with open('valores_celulares.txt', 'w') as arquivo:
  for valor in valores_celulares:
   arquivo.write(str(valor) + '\n')

# %%
#criar e modificar arquivos
valores_celulares = [850, 2230, 1500, 3500, 5000]
#'r' -> Ler algo
#'w' -> somente escrever algo
#'r+' -> usado para ler e escrever algo
#'a' - > usado para acrescentar algo
with open('valores_celulares.txt', 'a') as arquivo:
  for valor in valores_celulares:
   arquivo.write(str(valor) + '\n')

# %%
#criar e modificar arquivos
valores_celulares = [850, 2230, 1500, 3500, 5000]
#'r' -> Ler algo
#'w' -> somente escrever algo
#'r+' -> usado para ler e escrever algo
#'a' - > usado para acrescentar algo
with open('valores_celulares.txt', 'r') as arquivo:
  for valor in valores_celulares:
   print(valor)
# Out:
# 850
# 2230
# 1500
# 3500
# 5000

# %%
#criar e modificar arquivos
valores_celulares = [850, 2230, 1500, 3500, 5000]
#'r' -> Ler algo
#'w' -> somente escrever algo
#'r+' -> usado para ler e escrever algo
#'a' - > usado para acrescentar algo
with open('valores_celulares.txt', 'r') as arquivo:
  for valor in arquivo:
   print(valor)
# Out:
# 850
#
# 2230
#
# 1500
#
# 3500
#
# 5000
#
# 850
#
# 2230
#
# 1500
#
# 3500
#
# 5000
#
# 850
#
# 2230
#
# 1500
#
# 3500
#
# 5000

# %%
#criar e modificar arquivos
valores_celulares = [850, 2230, 1500, 3500, 5000]
#'r' -> Ler algo
#'w' -> somente escrever algo
#'r+' -> usado para ler e escrever algo
#'a' - > usado para acrescentar algo
with open('valores_celulares.txt', 'r+') as arquivo:
  for valor in arquivo:
      print(valor)
  arquivo.write('9000')
# Out:
# 850
#
# 2230
#
# 1500
#
# 3500
#
# 5000
#
# 850
#
# 2230
#
# 1500
#
# 3500
#
# 5000
#
# 850
#
# 2230
#
# 1500
#
# 3500
#
# 5000
#
# 9000
